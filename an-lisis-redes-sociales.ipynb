# %% [markdown]
# # **REDES SOCIALES**

# %% [markdown]
# ![1.jpg](attachment:3aee4968-193f-4b0b-95dd-f195236facf0.jpg)

# %% [markdown]
# Las redes sociales cuentan con 4.620 millones de usuarios en el mundo, lo que equivale al 58% de la población, según el estudio Digital 2022 Global Overview Repor.
#
# Es decir, actualmente en el mundo hay 4.620 millones de personas usando estas herramientas. De este total, 424 millones fueron tentados por las redes en 2021, lo que equivale a 1 millón de usuarios nuevos por día o aproximadamente 13 suscriptores nuevos cada segundo

# %% [markdown]
# ![2.jpg](attachment:332f2e28-8ed7-4e84-aa82-61ced378aac0.jpg)

# %% [markdown]
# Comencemos con un vistazo a los últimos titulares sobre el "estado digital" global:
#
# * La población mundial superó los 8 000 millones el 15 de noviembre de 2022 y alcanzó los 8 010 millones a principios de 2023. Un poco más del 57 % de la población mundial ahora vive en áreas urbanas.
# * Un total de 5440 millones de personas utilizan teléfonos móviles a principios de 2023, lo que equivale al 68 % de la población mundial total. Los usuarios móviles únicos aumentaron un poco más del 3 por ciento durante el año pasado, con 168 millones de nuevos usuarios en los últimos 12 meses.*
# * Actualmente hay 5.160 millones de usuarios de Internet en el mundo, lo que significa que el 64,4 por ciento de la población total del mundo está ahora en línea. Los datos muestran que el total de usuarios de Internet en todo el mundo aumentó un 1,9 % en los últimos 12 meses, pero los retrasos en la presentación de datos significan que el crecimiento real probablemente será mayor de lo que sugiere esta cifra.*
# * Ahora hay 4.760 millones de usuarios de redes sociales en todo el mundo, lo que equivale a poco menos del 60 por ciento de la población mundial total. Sin embargo, el crecimiento de los usuarios de las redes sociales se ha desacelerado en los últimos meses, con la adición neta de este año de 137 millones de nuevos usuarios, lo que equivale a un crecimiento anual de solo el 3 por ciento.

# %% [markdown]
# # Uso de telefonos moviles

# %% [markdown]
# **PASO 1**
#
# **Importación de librerias**.
#
# Estas líneas de código son comunes al comienzo de muchos scripts de Python que utilizan las bibliotecas Pandas y NumPy.
#
# Al importar estas bibliotecas, se hace referencia a ellas utilizando los alias pd y np, respectivamente, en el resto del código. Esto permite acceder a las funciones y métodos proporcionados por estas bibliotecas para realizar operaciones de análisis de datos y cálculos numéricos.

# %%
import pandas as pd
import numpy as np
import os;
os.listdir('/kaggle/input/')
# Out:
# ['telefonos-celulares', 'internetuso', 'nointernet', 'usoredes']

# %% [markdown]
# **PASO 2**
#
# Usamos la función **read_csv()** de la biblioteca Pandas para leer un archivo CSV.
#
# Después de ejecutar esta línea de código, el archivo CSV se carga en el DataFrame *cel*, lo que te permite acceder y manipular los datos contenidos en él.

# %%
cel = pd.read_csv('/kaggle/input/telefonos-celulares/redesSociales.csv')
cel.head()
# Out:
#   UsoDeTelefonosMoviles  Poblacion  Porcetaje
# 0                    Si       5440         68
# 1                    No       2560         32

# %% [markdown]
# **PASO 3**
#
# La función **print()**, permite mostrar en la consola el contenido de la variable cel.
#
# En este caso, se está imprimiendo la primera fila del DataFrame cel.

# %%
print (cel[:1])
# Out:
#   UsoDeTelefonosMoviles  Poblacion  Porcetaje
# 0                    Si       5440         68

# %% [markdown]
# **PASO 4**
#
# Mediante la función **print()**, se muestra en la consola las columnas 'UsoDeTelefonosMoviles' y 'Porcentaje' del DataFrame cel.

# %%
print (cel[['UsoDeTelefonosMoviles','Porcetaje']])
# Out:
#   UsoDeTelefonosMoviles  Porcetaje
# 0                    Si         68
# 1                    No         32

# %% [markdown]
# **PASO 5**
#
# Se hace uso de la función **print()** para mostrar en la consola la suma de los valores de la columna 'Poblacion' del DataFrame cel.

# %%
print (sum(cel['Poblacion']))
# Out:
# 8000

# %% [markdown]
# **PASO 6**
#
# La expresión **cel['Porcentaje'] < 50** crea una máscara booleana que evalúa si cada valor en la columna 'Porcentaje' es menor que 50.

# %%
print (cel[cel['Porcetaje']<50])
# Out:
#   UsoDeTelefonosMoviles  Poblacion  Porcetaje
# 1                    No       2560         32

# %% [markdown]
# **PASO 7**
#
# La siguiente linea es comúnmente utilizada al trabajar con gráficos en Python utilizando la biblioteca **matplotlib.**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **PASO 8**
#
# Mediante la función **bar()**, del módulo matplotlib.pyplot, se crea un gráfico de barras.
#
# El gráfico de barras muestra la relación entre dos conjuntos de datos: **cel['UsoDeTelefonosMoviles'] y cel['Poblacion'].**
#
# Y mediante la función **show()** se muestra el gráfico en una ventana o en la salida de la consola

# %%
plt.bar(cel['UsoDeTelefonosMoviles'], cel['Poblacion'])
plt.show()

# %% [markdown]
# **PASO 9**
#
# De los datos obtenidos tetenos que del tootal de las poblacion que es 8000, tenemos que el 68% siendo un tottal de 5440 personas, hacen uso de dispositivos moviles, mientas que el 32% que es al rededor de 2560 millonees de perosnas no hacen uso de dispositivos moviles.

# %%
plt.bar(cel['UsoDeTelefonosMoviles'], cel['Porcetaje'])
plt.show()

# %% [markdown]
# # Uso de Internet por país

# %%
import pandas as pd
import numpy as np

# %%
red = pd.read_csv('/kaggle/input/internetuso/internet.csv')
red.head()
# Out:
#             Pais  PorcetajePoblacional
# 0  EstadosUnidos                  91.8
# 1     ReinoUnido                  97.8
# 2          Rusia                  88.2
# 3  ArabiaSaudita                  99.0
# 4          China                  73.7

# %%
red
# Out:
#               Pais  PorcetajePoblacional
# 0    EstadosUnidos                  91.8
# 1       ReinoUnido                  97.8
# 2            Rusia                  88.2
# 3    ArabiaSaudita                  99.0
# 4            China                  73.7
# 5          Irlanda                  99.0
# 6          Noruega                  99.0
# 7        Australia                  96.2
# 8         CoreaSur                  97.6
# 9            Suiza                  98.4
# 10       Dinamarca                  98.1
# 11          Espana                  94.9
# 12          Suecia                  97.2
# 13  EmiratosArabes                  99.0
# 14          Egipto                  72.2
# 15          Brazil                  84.3
# 16           Chile                  90.2
# 17         Francia                  92.6
# 18          Italia                  86.1
# 19          Canada                  93.8
# 20        Alemania                  93.1
# 21        Colombia                  75.7
# ...

# %%
# que columnas tienen los datos?
red.columns
# Out:
# Index(['Pais', 'PorcetajePoblacional'], dtype='object')

# %%
# qué tamaño tienen los datos?
red.shape
# Out:
# (50, 2)

# %%
# hay valores nulos en los datos?
red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Pais                  50 non-null     object
#  1   PorcetajePoblacional  50 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 928.0+ bytes

# %%
# como se distribuyen las variables numéricas
red.describe()
# Out:
#        PorcetajePoblacional
# count             50.000000
# mean              86.296000
# std               13.573849
# min               32.700000
# 25%               83.025000
# 50%               90.250000
# 75%               95.800000
# max               99.000000

# %%
# como se comportan las variables categóricas
red.describe(include=['O'])
# Out:
#                  Pais
# count              50
# unique             50
# top     EstadosUnidos
# freq                1

# %%
red.groupby(['PorcetajePoblacional']).count()['Pais']
# Out:
# PorcetajePoblacional
# 32.7    1
# 48.7    1
# 54.4    1
# 68.2    1
# 72.2    1
# 72.3    1
# 73.1    1
# 73.7    1
# 75.7    1
# 77.0    1
# 78.6    1
# 79.1    1
# 82.9    1
# 83.4    1
# 84.0    1
# 84.3    1
# 85.1    1
# 85.3    1
# 86.1    1
# 87.2    1
# 88.1    1
# 88.2    1
# 88.4    1
# 88.9    1
# 90.2    1
# 90.3    1
# 90.7    1
# 91.6    1
# 91.8    1
# 92.6    1
# 93.1    2
# 93.8    1
# 94.2    1
# 94.5    1
# 94.9    1
# 95.5    1
# 95.9    1
# 96.2    1
# 96.8    1
# 96.9    1
# 97.2    1
# 97.6    1
# 97.8    1
# 98.1    1
# 98.4    1
# 99.0    4
# Name: Pais, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(red['PorcetajePoblacional'], red['Pais'])
plt.show()

# %%
print (red[red['PorcetajePoblacional']<70.0])
# Out:
#        Pais  PorcetajePoblacional
# 24    India                  48.7
# 26  Nigeria                  54.4
# 27    Ghana                  68.2
# 49    Kenia                  32.7

# %%
print (red[red['PorcetajePoblacional']>95.0])
# Out:
#               Pais  PorcetajePoblacional
# 1       ReinoUnido                  97.8
# 3    ArabiaSaudita                  99.0
# 5          Irlanda                  99.0
# 6          Noruega                  99.0
# 7        Australia                  96.2
# 8         CoreaSur                  97.6
# 9            Suiza                  98.4
# 10       Dinamarca                  98.1
# 12          Suecia                  97.2
# 13  EmiratosArabes                  99.0
# 34        Singapur                  96.9
# 35         Malasia                  96.8
# 36     PaisesBajos                  95.5
# 44    NuevaZelanda                  95.9

# %%
plt.bar(red['PorcetajePoblacional'], red['Pais'])
plt.show()

# %% [markdown]
# # Población no conectada

# %% [markdown]
# ![3.jpg](attachment:fcfd4c45-7c8c-430e-9412-db1cd61ab9ee.jpg)

# %% [markdown]
# **PASO 1**
#
# **Importación de librerias**
#
# Hacemos uso de pandas y numpy debido a su amplio uso en el análisis de datos y la manipulación de matrices numéricas.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **PASO 2**
#
# Subimos el archivo generado en CSV, y lo almacenamos en una variable llamada **nred**, luego mediante el comando **head()** mostramos en una tabla los datos generados.

# %%
nred = pd.read_csv('/kaggle/input/nointernet/nointernet.csv')
nred.head()
# Out:
#          Pais PoblacionDesconectada GranNumeroPoblacional  \
# 0       India             730027000                    si
# 1       China             374709000                    si
# 2    Pakistan             150779000                    si
# 3  Bangladesh             105138000                    si
# 4    Ethiopia             104073000                    si
#
#   NivelesBajosDeAdopcionDeInternet  Porcentaje
# 0                               no        51.3
# 1                               no        26.3
# 2                               no        63.3
# 3                               no        61.1
# 4                               si        83.3

# %%
nred
# Out:
#                         Pais PoblacionDesconectada GranNumeroPoblacional  \
# 0                      India             730027000                    si
# 1                      China             374709000                    si
# 2                   Pakistan             150779000                    si
# 3                 Bangladesh             105138000                    si
# 4                   Ethiopia             104073000                    si
# 5                    Nigeria              98635000                    si
# 6             RepublicaCongo              77568000                    si
# 7                  Indonesia              63514000                    si
# 8                   Tanzania              45456000                    si
# 9                      Kenya              36699000                    si
# 10                CoreaNorte           desconocido                    no
# 11                  SudanSur              10233000                    no
# ...

# %% [markdown]
# **PASO 3**
#
# Mediante la función **shape()**, se podra conocer las dimensiones de los datos, permitiendo conocer el número de filas y columnas que contiene.

# %%
# qué tamaño tienen los datos?
nred.shape
# Out:
# (19, 5)

# %% [markdown]
# **PASO 4**
#
# La siguiente línea de código imprimirá la primera fila del DataFrame "nred" en la consola.

# %%
print (nred.loc[0])
# Out:
# Pais                                    India
# PoblacionDesconectada               730027000
# GranNumeroPoblacional                      si
# NivelesBajosDeAdopcionDeInternet           no
# Porcentaje                               51.3
# Name: 0, dtype: object

# %% [markdown]
# **PASO 5**
#
# Mediante el comando **print()**, se imprimirá en la consola las columnas "Pais" y "PoblacionDesconectada" del DataFrame "nred".
# Con ello se podra identificar el total de pesonas desconectadas deacuerdo al analisis de cada uno de los paises.

# %%
print (nred[['Pais','PoblacionDesconectada']])
# Out:
#                         Pais PoblacionDesconectada
# 0                      India             730027000
# 1                      China             374709000
# 2                   Pakistan             150779000
# 3                 Bangladesh             105138000
# 4                   Ethiopia             104073000
# 5                    Nigeria              98635000
# 6             RepublicaCongo              77568000
# 7                  Indonesia              63514000
# 8                   Tanzania              45456000
# 9                      Kenya              36699000
# 10                CoreaNorte           desconocido
# 11                  SudanSur              10233000
# 12               Afghanistan              34008000
# 13                Madagascar              24061000
# 14                      Chad              14776000
# 15                Mozonbique              26504000
# 16  RepublicaCentralAfricana               5058000
# ...

# %% [markdown]
# **PASO 6**
#
# Mediante la función **sum()**, se conocera la suma del procentaje de la poblacion desconectada, la cual se almacenara dentro de la variable 'por'.
#
# Seguido de eso generamos una nueva variable que permita conocer el total de población desconectada, decuerdo a la muestra de paises analisados.

# %%
por=sum(nred['Porcentaje'])
totalporciento=por/19
print(totalporciento)
# Out:
# 71.12105263157895

# %% [markdown]
# **PASO 7**
#
# La condición utilizada es **nred['Porcentaje']>80**, lo que significa que se seleccionarán las filas donde el valor de la columna "Porcentaje" sea mayor que 80.

# %%
print (nred[nred['Porcentaje']>80])
# Out:
#                         Pais PoblacionDesconectada GranNumeroPoblacional  \
# 4                   Ethiopia             104073000                    si
# 10                CoreaNorte           desconocido                    no
# 11                  SudanSur              10233000                    no
# 12               Afghanistan              34008000                    no
# 13                Madagascar              24061000                    no
# 14                      Chad              14776000                    no
# 16  RepublicaCentralAfricana               5058000                    no
# 17                   Burundi              11734000                    no
# 18                   Somalia              16108000                    no
#
#    NivelesBajosDeAdopcionDeInternet  Porcentaje
# 4                                si        83.3
# 10                               si        99.9
# 11                               si        93.0
# ...

# %% [markdown]
# **PASO 8**
#
# Importamos la biblioteca **matplotlib** y se utiliza para crear visualizaciones gráficas en Python.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **PASO 9**
#
# Mediante la función **scatter()**, se generará un grafico de dispersión de los datos de las columnas "Porcentaje" y "Pais" del DataFrame "nred". Luego, se utiliza la función show para mostrar el gráfico en una ventana separada.

# %%
plt.scatter(nred['Porcentaje'], nred['Pais'])
plt.show()

# %% [markdown]
# **PASO 10**
#
# Usamos la función **bar** del módulo matplotlib.pyplot para crear un gráfico de barras

# %%
plt.bar(nred['Porcentaje'], nred['Pais'])
plt.show()

# %% [markdown]
# **PASO 11**
#
# Mediante el comando **groupby()**, se va agrupar los datos por los valores de la columna "NivelesBajosDeAdopcionDeInternet". Luego, se utiliza el método **count()** para contar el número de ocurrencias de cada valor en la columna "Pais".

# %%
nred.groupby(['NivelesBajosDeAdopcionDeInternet']).count()['Pais']
# Out:
# NivelesBajosDeAdopcionDeInternet
# no     9
# si    10
# Name: Pais, dtype: int64

# %% [markdown]
# **PASO 12**
#
# Nuevamente mediante el método **groupby()**, del DataFrame "nred", se va agrupar los datos por los valores de las columnas "NivelesBajosDeAdopcionDeInternet" y "GranNumeroPoblacional". Luego, se utiliza el método **count()** para contar el número de ocurrencias de cada combinación de valores en esas columnas. Finalmente, se utiliza el método head para mostrar las primeras filas del resultado.

# %%
dato=nred.groupby(['NivelesBajosDeAdopcionDeInternet','GranNumeroPoblacional']).count()['Pais']
dato.head()
# Out:
# NivelesBajosDeAdopcionDeInternet  GranNumeroPoblacional
# no                                si                       9
# si                                no                       9
#                                   si                       1
# Name: Pais, dtype: int64

# %% [markdown]
# **PASO 13**
#
# Finalmente se graficara lo almacenado dentro de la variable **dato**,para ello haciendo uso del metodo **unstack** para poder reorganizar los datos en un formato más conveniente para la visualización. Luego, se utiliza el método **plot.bar()** para crear un gráfico de barras a partir de los datos reorganizados. Finalmente, se utiliza **plt.show()** para mostrar el gráfico en una ventana separada.

# %%
dato = nred.groupby(['NivelesBajosDeAdopcionDeInternet','GranNumeroPoblacional']).count()['Pais']
print(dato)
(dato.unstack(level=0).plot.bar())
plt.show()
# Out:
# NivelesBajosDeAdopcionDeInternet  GranNumeroPoblacional
# no                                si                       9
# si                                no                       9
#                                   si                       1
# Name: Pais, dtype: int64

# %%
plt.plot(nred['NivelesBajosDeAdopcionDeInternet'], nred['Pais'])
plt.show()

# %% [markdown]
# # Redes sociales mas populares

# %% [markdown]
# **PASO 1**
#
# Importa las bibliotecas pandas, numpy y matplotlib.pyplot.
#
# **Pandas** permitira manipular y analizar conjuntos de datos tabulares.
#
# **Numpy** permitira realizar un análisis de datos.
#
# **matplotlib** que proporciona una interfaz similar a la de MATLAB para crear gráficos y visualizaciones en Python.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **PASO 2**
#
# Se crea una variable en la cual se pueda leer el archivo CSV.
#
# Por otro lado mediante la función **read_csv()** de la biblioteca pandas se podrá leer los archivos CSV, y con la función **head()** se mostrara por cosola los primero 5 elementos del dataframe

# %%
s = pd.read_csv('/kaggle/input/usoredes/SocialNetworks.csv')
s.head()
# Out:
#      Country  WhatsApp  Facebook  YouTube  Instagram
# 0     Brazil     100.3     130.0    127.1      109.6
# 1      India     465.0     376.0    439.7      317.7
# 2        USA     199.8     295.8    253.2      168.8
# 3  Indonesia     272.7     183.7    269.4      147.5
# 4     Mexico     120.8      83.3    119.8       79.1

# %% [markdown]
# **PASO 3**
#
# Mediante el comando **head()** tambien se puede especificar los datos que se desea mostrar por cosola.

# %%
s.head(10)
# Out:
#      Country  WhatsApp  Facebook  YouTube  Instagram
# 0     Brazil    100.30    130.00   127.10      109.6
# 1      India    465.00    376.00   439.70      317.7
# 2        USA    199.80    295.80   253.20      168.8
# 3  Indonesia    272.70    183.70   269.40      147.5
# 4     Mexico    120.80     83.30   119.80       79.1
# 5      Rusia     75.70     72.60    73.50       58.2
# 6     Turkey     62.10     59.10    61.40       47.7
# 7      Japan     70.50     58.40    70.20       52.4
# 8      China      1.90    626.00   715.00      447.0
# 9    Ecuador     16.89     12.76     7.64        6.1

# %% [markdown]
# **PASO 4**
#
# El comando **plt.scatter()** crea un gráfico de dispersión utilizando los datos de la columna 'Facebook' del DataFrame **s** en el eje x y los datos de la columna 'Country' en el eje y.
#
# El comando **tilte()** establece un título para el gráfico.
#
# El comado **show()**  muestra el gráfico en una ventana separada.

# %%
plt.scatter(s['Facebook'], s['Country'])
plt.title("Uso de Facebook")
plt.show()

# %% [markdown]
# **PASO 5**
#
# El comando **plt.plot()** crea un gráfico de líneas utilizando los datos del DataFrame **s**.

# %%
plt.plot(s['YouTube'], s['Country'])
plt.title("Uso de Youtube")
plt.show()

# %% [markdown]
# **PASO 6**
#
# El comando **plt.boxplot()** crea un gráfico de diagrama de caja utilizando los datos de la columna 'Instagram' del DataFrame s. Un diagrama de caja muestra la distribución de un conjunto de datos, incluyendo la mediana, los cuartiles y los valores atípicos.
#
# El argumento **vert=False** indica que el gráfico se mostrará horizontalmente.
#
# El argumento **patch_artist=True** indica que se utilizarán colores para rellenar las cajas en el gráfico.
#
# El argumento **labels=["Instagram"]** establece la etiqueta del eje x como "Instagram".

# %%
plt.boxplot(s["Instagram"], vert=False, patch_artist=True, labels=["Instagram"])
plt.show()

# %% [markdown]
# **PASO 7**
#
# Esta línea de código crea un gráfico de diagrama de caja utilizando los datos de las columnas 'Instagram' y 'WhatsApp' del DataFrame **s**

# %%
plt.boxplot([s["Instagram"], s["WhatsApp"]], vert=False, patch_artist=True, labels=["Instagram","WhatsApp"])
plt.show()

# %% [markdown]
# **PASO 8**
#
# El comando **describe()** muestra un resumen estadístico de los datos en el DataFrame **s.**
#
# El resumen incluye información como el número de elementos, la media, la desviación estándar, los valores mínimo y máximo, y los percentiles de los datos en cada columna del DataFrame.

# %%
s.describe()
# Out:
#          WhatsApp    Facebook     YouTube   Instagram
# count   10.000000   10.000000   10.000000   10.000000
# mean   138.569000  189.766000  213.694000  143.410000
# std    140.631676  191.647773  218.393504  138.259888
# min      1.900000   12.760000    7.640000    6.100000
# 25%     64.200000   62.475000   71.025000   53.850000
# 50%     88.000000  106.650000  123.450000   94.350000
# 75%    180.050000  267.775000  265.350000  163.475000
# max    465.000000  626.000000  715.000000  447.000000

# %% [markdown]
# **PASO 9**
#
# En la línea de código **s['Instagram']** se accede a la columna 'Instagram' del DataFrame **s** y devuelve los datos contenidos en esa columna.

# %%
s['Instagram']
# Out:
# 0    109.6
# 1    317.7
# 2    168.8
# 3    147.5
# 4     79.1
# 5     58.2
# 6     47.7
# 7     52.4
# 8    447.0
# 9      6.1
# Name: Instagram, dtype: float64

# %% [markdown]
# **PASO 10**
#
# El comando **max()** devuelve el valor máximo de la columna 'Instagram'.

# %%
#me da el valor maximo
s['Instagram'].max()
# Out:
# 447.0

# %% [markdown]
# **PASO 11**
#
# El comando **value_counts()** cuenta la cantidad de veces que aparece cada valor único en la columna 'Instagram' del DataFrame **s** y devuelve los resultados en orden descendente.

# %%
#analisis de frecuencias
s['Instagram'].value_counts()
# Out:
# 109.6    1
# 317.7    1
# 168.8    1
# 147.5    1
# 79.1     1
# 58.2     1
# 47.7     1
# 52.4     1
# 447.0    1
# 6.1      1
# Name: Instagram, dtype: int64

# %% [markdown]
# **PASO 12**
#
# Deacurdo a los datos obtenidos se realiza las respectivas gráficas.
#
# **plot.bar()** me muestra un diagrama de barras en general de cada una de las redes sociales.
#
# **plot()** me muestra un diagrama de lineas en general de cada una de las redes sociales.
#
# **plot.box()** genera un gráfico de caja utilizando los datos del DataFrame **s**.

# %%
s
# Out:
#      Country  WhatsApp  Facebook  YouTube  Instagram
# 0     Brazil    100.30    130.00   127.10      109.6
# 1      India    465.00    376.00   439.70      317.7
# 2        USA    199.80    295.80   253.20      168.8
# 3  Indonesia    272.70    183.70   269.40      147.5
# 4     Mexico    120.80     83.30   119.80       79.1
# 5      Rusia     75.70     72.60    73.50       58.2
# 6     Turkey     62.10     59.10    61.40       47.7
# 7      Japan     70.50     58.40    70.20       52.4
# 8      China      1.90    626.00   715.00      447.0
# 9    Ecuador     16.89     12.76     7.64        6.1

# %%
s.plot.bar()
# Out:
# <Axes: >

# %%
s.plot()
# Out:
# <Axes: >

# %%
s.plot.box()
# Out:
# <Axes: >
